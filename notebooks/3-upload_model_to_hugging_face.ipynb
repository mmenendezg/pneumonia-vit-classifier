# %% [markdown]
# # Setup

# %%
import os

from huggingface_hub import push_to_hub_keras, from_pretrained_keras, notebook_login
from transformers import TFAutoModel
from keras import models

# %%
# !huggingface-cli login --token $HUGGINGFACE_TOKEN
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /Users/mmenendezg/.cache/huggingface/token
# Login successful

# %%
model_checkpoint = "../models/pneumonia_classifier/"
pneumonia_classifier = models.load_model(model_checkpoint)
push_to_hub_keras(pneumonia_classifier, "vit_pneumonia_classifier")
# Out:
# INFO:tensorflow:Assets written to: /var/folders/lj/b6nh4d2n3_b608c7t9s86ybc0000gn/T/tmpbmvm56x4/mmenendezg/vit_pneumonia_classifier/assets
# INFO:tensorflow:Assets written to: /var/folders/lj/b6nh4d2n3_b608c7t9s86ybc0000gn/T/tmpbmvm56x4/mmenendezg/vit_pneumonia_classifier/assets
# fingerprint.pb:   0%|          | 0.00/55.0 [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
# fingerprint.pb: 100%|██████████| 55.0/55.0 [00:00<00:00, 285B/s]
# fingerprint.pb: 100%|██████████| 55.0/55.0 [00:00<00:00, 178B/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# keras_metadata.pb: 100%|██████████| 353k/353k [00:00<00:00, 607kB/s]
#
#
#
# saved_model.pb: 100%|██████████| 6.79M/6.79M [00:00<00:00, 7.87MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
model = from_pretrained_keras("mmenendezg/vit_pneumonia_classifier")
# Out:
# config.json not found in HuggingFace Hub.
# WARNING:huggingface_hub.hub_mixin:config.json not found in HuggingFace Hub.
# ...
# Fetching 7 files:  14%|█▍        | 1/7 [00:00<00:03,  1.81it/s]
#
#
#
#
# ...
# Fetching 7 files:  71%|███████▏  | 5/7 [00:00<00:00,  6.33it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
# Fetching 7 files: 100%|██████████| 7/7 [00:07<00:00,  1.01s/it]
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
model.summary()
# Out:
# Model: "pneumonia_classifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  sequential (Sequential)     (None, 3, 224, 224)       0
#
#  tf_vi_t_model (TFViTModel)  multiple                  86389248
#
#  dense (Dense)               multiple                  769
#
#  flatten (Flatten)           multiple                  0
#
# ...
# Total params: 86390017 (329.55 MB)
# Trainable params: 86390017 (329.55 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
